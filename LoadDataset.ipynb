# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn  as sn

# %% [markdown]
# # 1. Generating Dataset

# %%
# Carga los datos 
dataCash = pd.read_csv('../projectGPForecasting/Data/CashierData.csv', sep=';', decimal=',')
# Visualiza las primeras instancias
print(dataCash.shape)
dataCash.head(-10)
# Out:
# (1359, 17)
#             Date  CutFlowers  PotOwn  PotPurchased  Wholesale  FruitsVegs  \
# 0     2016-12-12       12.00     0.0          0.00       0.00        0.00
# 1     2016-12-13       32.00     2.9         68.25       0.00        8.40
# 2     2016-12-14      140.00     0.0          5.00       0.00        9.35
# 3     2016-12-15      126.90     0.0         61.00       0.00        6.90
# 4     2016-12-16      279.50     0.0         59.40       0.00       14.30
# ...          ...         ...     ...           ...        ...         ...
# 1344  2020-08-17      311.15    90.5         16.00       0.00       11.00
# 1345  2020-08-18      288.70   125.5         62.50      59.47       21.30
# 1346  2020-08-19      335.60    33.0         50.30       0.00       30.45
# 1347  2020-08-20      325.50   142.0         16.00      28.78       24.00
# 1348  2020-08-21      266.90    55.0         43.90       0.00       28.50
#
#       Commodity  mean_temp  mean_humid  mean_prec_height_mm  \
# ...
